# %% [markdown]
# # FIFA 19
#
# This can help player to have good abilities at earlier age.
# We begin by exploring how many actual players have potential per natioanlity and age. Because during the last World Cup, Kylian Mbappe became famous by winning the World Cup woth France by the age of 19 years old. This call my attention, how old you need to be in order to be famous in soccer (good wage)?
#
# We find 23 years old is the mean of famous players even though most of the players have between 21-26 years.
#
# Finally, we conlude by the age of 25+ you are famous because your wage will be about 140K euros.
#
#
# Appendix 1: shows the basic metrics of all variables, mean, standard desviation, min, max and quartils
#
# Appendix 2: The classification by nationality, confirms that the countries that have won at least one world cup have more players. May be because the investment of infraestructure during the world cups host are being used nowadays by more population. This can help player to have good abilities at earlier age.

# %% [markdown]
# ## Data exploring
#
# FIFA is an organization which describes itself as an international governing body of association soccer, futsal, beach soccer and eFootball. Every year a videogame comes out with the stats of the season of each active player worldwide.
#
# The original file was downloaded from Kaggle so I explore the data and clean it by delete the players with missing data. Then, convert it in pandas Dataframe format. Did a couple of methods to explore the variables such as K-mean, correlation, Shapiro-Wilk, D’Agostino’s K^2 and Anderson-Darling test and a couple of plots such as histogram, scatterplot, boxplot, regression.
#
# Convert the needed variables into a new CSV file in order to to make the following analysis.

# %%
import pandas as pd
import seaborn as sns

# %%
data=pd.read_csv('C:/Users/juan_/Documents/U/Semestre 13/Elements Machine Learning/Project/Enviar/data_final.csv', index_col=0)
df=pd.DataFrame(data)

# %% [markdown]
# ## Histogram of age
#
# Easier to visualize the distribution of the players by age. Most of them have 20-27 years old. Appendix 1: confirms the distribution shown here.

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\juan_\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Linear regression
#
# Check the relationship of the salary by the age of the famous players. The age (experience) playing is significant to the wage of the player since they become more famous.
#
# Appendix 4: shows the higher the potential then the wage is better except for the player with 95 Potential.
#
# Appendix 5: shows the mean of wage per potential score in order to help visualize the linear regression.

# %%
 sns.lmplot(x="Age", y="Wage", data=df)

# %% [markdown]
# ## Appendix 1: Basic metrics of all variables
#
# The wage is presented in thousand of Euro. The potential is higher than 85 due to those where choosen from the original data.
#
# The most important specific personal stats of a player when playing the videogame are: BallControl, Acceleration, SprintSpeed, Agility and Stamina, since you want a player who can run with good acceleration and endurance but controling the ball.

# %%
df.describe()
# Out:
#               Age   Potential        Wage  BallControl  Acceleration  \
# count  260.000000  260.000000  260.000000   260.000000    260.000000
# mean    23.503846   87.911538  103.123077    74.546154     74.607692
# std      4.132458    1.946153   95.187157    17.966340     13.293826
# min     16.000000   86.000000    1.000000    10.000000     25.000000
# 25%     21.000000   86.000000   27.750000    73.000000     68.000000
# 50%     23.000000   87.000000   81.500000    80.000000     76.000000
# 75%     26.000000   89.000000  146.250000    84.250000     85.000000
# max     40.000000   95.000000  565.000000    96.000000     97.000000
#
#        SprintSpeed     Agility     Stamina
# count   260.000000  260.000000  260.000000
# mean     74.957692   73.876923   72.426923
# std      12.247218   13.532752   14.585338
# min      23.000000   26.000000   19.000000
# 25%      68.000000   65.000000   68.000000
# 50%      76.000000   77.000000   75.000000
# ...

# %% [markdown]
# ## Appendix 2 Count players per country
#
# Most of the counties with more than 5 players have played a final during the world cup tournament. By performing well at one world cup, the government tries to invest more on the soccer team. Costa Rica is the example since on the second last world cup, they perfom well and made national history. The government invested more in order to rank better on the last championship.

# %%
df.groupby(['Nationality']).size().reset_index(name='Players')
# Out:
#            Nationality  Players
# 0              Albania        2
# 1            Argentina        7
# 2              Austria        1
# 3              Belgium        9
# 4   Bosnia Herzegovina        1
# 5               Brazil       26
# 6               Canada        1
# 7           Cape Verde        1
# 8             Colombia        1
# 9           Costa Rica        1
# 10             Croatia        3
# 11      Czech Republic        1
# 12             Denmark        2
# 13               Egypt        1
# 14             England       14
# 15              France       37
# 16               Gabon        1
# 17             Georgia        1
# 18             Germany       23
# 19               Ghana        1
# 20              Greece        1
# 21              Guinea        2
# 22               Italy       23
# 23         Ivory Coast        1
# 24             Jamaica        1
# 25      Korea Republic        1
# 26              Mexico        1
# 27          Montenegro        1
# ...

# %% [markdown]
# ## Appendix 3 Correlation between player attributes
#
# The hability variables don't have a correlation with wage nor potential. Potential and wage have about .8 which is high.

# %%
 # Heatmap
sns.heatmap(df.corr())

# %% [markdown]
# ## Appendix 4 Potential relationship to the wage of each player
#
# Visualize the relationship between Potential and Wage except for the player with 95 of Potential

# %%
 sns.lmplot(x="Potential", y="Wage", data=df)

# %% [markdown]
# ## Appendix 5 Mean wage per Potential
#
# A groupby per Potential and calculate the mean of the wage of the players with that potential.

# %%
df.groupby('Potential', as_index=False)['Wage'].mean()
# Out:
#    Potential        Wage
# 0         86   60.223684
# 1         87   81.915254
# 2         88   91.911111
# 3         89  116.580645
# 4         90  152.600000
# 5         91  251.250000
# 6         92  182.555556
# 7         93  166.750000
# 8         94  391.666667
# 9         95  100.000000

# %% [markdown]
# ## Appendix 6 Countries aggregate player ratings

# %%
sns.boxplot(x='Nationality', y="Potential", data=df)

# %% [markdown]
# ## Appendix 7 Player earnings per country

# %%
sns.boxplot(x='Nationality', y="Wage", data=df)

# %% [markdown]
# ## Appendix 8 Mean wage versus Age

# %%
sns.boxplot(x='Age', y="Wage", data=df)

# %% [markdown]
# # Prediction
#
# There are so many variables that we can't control in order to predict good players. In case we would like to do the machine learning models, used Random Forests and Logistic Regression. Here are some examples of good players that have lost overall rating by their behavior.
#
# Zinedine Zidane was a good attacking midfielder but retired with a red card on his last international game. The following quote helps me explain my point:
#     'The front page of L'Equipe asked, "What should we tell our children, for whom you have become an example for ever? ... How could that happen to a man like you?"'
#
# Mbapppe is 20 year old from France, plays at PSG. On the Coupe de France final, received a direct red card due to a fault. His attitude was like nothing happen and that the defender of the opposite team just felt.
